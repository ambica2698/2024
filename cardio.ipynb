# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from jupyterthemes import jtplot
jtplot.style(theme="monokai", context="notebook", ticks=True, grid=False)

# %%
df=pd.read_csv("/Users/ambicakalcoor/Desktop/csv/cardio_train.csv", sep=";")

# %%
df.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
df.tail(5)
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# 69995      1     0       1       0
# 69996      0     0       1       1
# 69997      0     1       0       1
# 69998      0     0       0       1
# 69999      0     0       1       0

# %%
df=df.drop(columns="id")

# %%
df["age"]= df["age"]/365

# %%
df.head()
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0  50.391781       2     168    62.0    110     80            1     1      0
# 1  55.419178       1     156    85.0    140     90            3     1      0
# 2  51.663014       1     165    64.0    130     70            3     1      0
# 3  48.282192       2     169    82.0    150    100            1     1      0
# 4  47.873973       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
df.describe()
# Out:
#                 age        gender        height        weight         ap_hi  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean      53.339358      1.349571    164.359229     74.205690    128.817286
# std        6.759594      0.476838      8.210126     14.395757    154.011419
# min       29.583562      1.000000     55.000000     10.000000   -150.000000
# 25%       48.394521      1.000000    159.000000     65.000000    120.000000
# 50%       53.980822      1.000000    165.000000     72.000000    120.000000
# 75%       58.430137      2.000000    170.000000     82.000000    140.000000
# max       64.967123      2.000000    250.000000    200.000000  16020.000000
#
#               ap_lo   cholesterol          gluc         smoke          alco  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean      96.630414      1.366871      1.226457      0.088129      0.053771
# ...

# %%
df.hist(bins=30, figsize=(20,20),color='r')
plt.show()

# %%
corr_matrix=df.corr()
corr_matrix
# Out:
#                   age    gender    height    weight     ap_hi     ap_lo  \
# age          1.000000 -0.022811 -0.081515  0.053684  0.020764  0.017647
# gender      -0.022811  1.000000  0.499033  0.155406  0.006005  0.015254
# height      -0.081515  0.499033  1.000000  0.290968  0.005488  0.006150
# weight       0.053684  0.155406  0.290968  1.000000  0.030702  0.043710
# ap_hi        0.020764  0.006005  0.005488  0.030702  1.000000  0.016086
# ap_lo        0.017647  0.015254  0.006150  0.043710  0.016086  1.000000
# cholesterol  0.154424 -0.035821 -0.050226  0.141768  0.023778  0.024019
# gluc         0.098703 -0.020491 -0.018595  0.106857  0.011841  0.010806
# smoke       -0.047633  0.338135  0.187989  0.067780 -0.000922  0.005186
# alco        -0.029723  0.170966  0.094419  0.067113  0.001408  0.010601
# active      -0.009927  0.005866 -0.006570 -0.016867 -0.000033  0.004780
# cardio       0.238159  0.008109 -0.010821  0.181660  0.054475  0.065719
#
# ...

# %%
plt.figure(figsize=(16,16))
sns.heatmap(corr_matrix, annot=True)
plt.show()

# %%
y=df['cardio']
x=df.drop(columns=['cardio'])

# %%
x.shape
# Out:
# (70000, 11)

# %%
y.shape
# Out:
# (70000,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
#shuffle=False to unshufle the set

# %%
x_train.shape
# Out:
# (56000, 11)

# %%
x_test.shape
# Out:
# (14000, 11)

# %%
x_train
# Out:
#              age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 28398  56.435616       1     160    60.0    120     80            3     3
# 1697   49.843836       2     165    80.0    120     80            1     2
# 64066  50.104110       1     160    83.0    140     90            1     1
# 10208  53.978082       1     166    98.0    140     90            3     3
# 32364  46.169863       1     168   108.0    150     90            2     2
# ...          ...     ...     ...     ...    ...    ...          ...   ...
# 55507  56.232877       1     164    66.0    140     90            1     1
# 47995  53.268493       1     165    70.0    120     80            1     1
# 18086  61.556164       1     148    70.0    130     80            1     1
# 40662  47.471233       2     175    61.0    110     70            1     1
# 19861  48.175342       2     176    90.0    130     90            2     1
#
#        smoke  alco  active
# 28398      0     0       1
# ...

# %%
y_train
# Out:
# 28398    1
# 1697     1
# 64066    1
# 10208    1
# 32364    0
#         ..
# 55507    0
# 47995    1
# 18086    1
# 40662    0
# 19861    0
# Name: cardio, Length: 56000, dtype: int64

# %%
# !pip install xgboost

# %%
from xgboost import XGBClassifier

# %%
xgb_classifier=XGBClassifier(objective="binary:logistic",eval_metric="error", learning_rate="0.1",max_depth=1, n_estimators=10)
xgb_classifier.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='error', feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate='0.1', max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=1, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=10, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
result=xgb_classifier.score(x_test, y_test)
print("Accuracy  :{}",format(result))
# Out:
# Accuracy  :{} 0.7066428571428571

# %%
y_predict=xgb_classifier.predict(x_test)
y_predict
# Out:
# array([1, 0, 0, ..., 0, 0, 1])

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.80      0.73      7058
#            1       0.75      0.62      0.68      6942
#
#     accuracy                           0.71     14000
#    macro avg       0.71      0.71      0.70     14000
# weighted avg       0.71      0.71      0.70     14000

# %%
from sklearn.metrics import confusion_matrix
cm= confusion_matrix(y_test,y_predict)
sns.heatmap(cm, fmt="d", annot=True)
# Out:
# <Axes: >

# %%
xgb_classifier=XGBClassifier(objective="binary:logistic",eval_metric="error", learning_rate="0.3",max_depth=10, n_estimators=10)
xgb_classifier.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='error', feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate='0.3', max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=10, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=10, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
result=xgb_classifier.score(x_test, y_test)
print("Accuracy  :{}",format(result))
# Out:
# Accuracy  :{} 0.7247857142857143

# %%
y_predict=xgb_classifier.predict(x_test)
y_predict
# Out:
# array([1, 0, 0, ..., 0, 0, 1])

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.76      0.74      7058
#            1       0.74      0.68      0.71      6942
#
#     accuracy                           0.72     14000
#    macro avg       0.73      0.72      0.72     14000
# weighted avg       0.73      0.72      0.72     14000

# %%
from sklearn.metrics import confusion_matrix
cm= confusion_matrix(y_test,y_predict)
sns.heatmap(cm, fmt="d", annot=True)
# Out:
# <Axes: >
